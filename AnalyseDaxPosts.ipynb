# %% [markdown]
# # Analyse DAX Posts

# %%
#Load file function
def load_file(filename):
    f = open(filename,'r')
    data = f.read()
    f.close()
    return data

# %% [markdown]
# ### Load and manipulate data

# %%
import json
import pandas as pd

#Set display properties
pd.set_option("display.line_width",500)
pd.set_option("display.width",1000)
#Load all WKN posts
messages = json.loads(load_file('db/dax_filtered.txt'))
#Transfer to pandas dataframe
db = pd.DataFrame.from_records(messages)
#Map name short
db['from_name'] = db['from'].map(lambda x: x['name'])
#Create time index
db = db.set_index(pd.to_datetime(db['created_time']))
#Sort for time when post was created
db = db.sort_index(ascending=False)

# %%
# Helper function for printing out single messages
def print_msg(row):
    print row['created_time']
    print row['message']
    if not pd.isnull(row['comments']):
        for ix, cmt in enumerate(row['comments']['data']):
            print 'Comment {}: '.format(ix+1) + cmt['message']

# %% [markdown]
# ### Set Long/Short, buy and stop

# %%
import re
# Set long/short
long_re = re.compile(r'^dax\s*long\s', re.IGNORECASE)
db['longshort'] = db['message'].apply(lambda _: 'long' if long_re.findall(_) else 'short')
# Set trade start
in_re = re.compile(r'\s[0-9]{4,5}\s', re.IGNORECASE)
db['in'] = db['message'].apply(lambda _: int(in_re.search(_).group()[1:-1]))
# Set stop
stop_re = re.compile(r'stop\s*([0-9]{4,5}|([0-9]{1,2}\spk))', re.IGNORECASE)
stop_re_std = re.compile(r'[0-9]{4,5}', re.IGNORECASE)
stop_re_pk = re.compile(r'[0-9]{1,2}\spk', re.IGNORECASE)
def get_stop(msg):
    s1 = stop_re.search(msg).group()
    s2 = stop_re_std.search(s1)
    s3 = stop_re_pk.search(s1)
    if s2:
        return int(s2.group())
    elif s3:
        return int(s3.group()[:-len(' pk')])
    else:
        raise Exception('Stop not found in msg ' + msg)

db['stop'] = db['message'].apply(get_stop)
for idx, stop in enumerate(db['stop']):
    if stop < 100:
        # The stop is denoted as distance from trade start
        db['stop'][idx] = (db['in'][idx] - stop) if (db['longshort'][idx] == 'long') else (db['in'][idx] + stop)

# %%
for i in range(0,50):
    print_msg(db.iloc[i])
    print db.iloc[i]['longshort']
    print db.iloc[i]['in']
    print db.iloc[i]['stop']
# Out:
# 2014-02-10T08:47:58+0000
# DAX LONG 9305 STOP 10 PK
# Comment 1: Stop einstand !
# Comment 2: 9325 TVK (50% , dadaurch hab ich minimum ein CRV von 1:1 weil stop 10 PK und 50 % nach 20 PK raus) !
# Comment 3: 9330 TVK
# Comment 4: 9345 tvk
# long
# 9305
# 9295
# 2014-02-07T13:39:04+0000
# DAX LONG 9241 STOP 10 PK ! IM LT ANGESAGT !
# Comment 1: 9262 TVK
# Comment 2: STOP EINSTAND NUN
# Comment 3: 9282 TVK
# Comment 4: 9295 TVK
# Comment 5: 9306 TKV
# Comment 6: 9341 tvk ! + 100 pk !!!
# long
# 9241
# 9231
# 2014-02-07T11:06:07+0000
# DAX SHORT 9278 STOP 10 PK
# Comment 1: 9263 TVK
# Comment 2: Stop einstand !
# Comment 3: + 15 PK ! Trade ende-----
# short
# 9278
# 9288
# 2014-02-07T09:24:24+0000
# DAX SHORT 9266 STOP 5 PK
# Comment 1: BLIND ??????
# Comment 2: - 5 PK
# short
# 9266
# 9271
# 2014-02-07T09:15:31+0000
# DAX SHORT 9258 STOP 9265
# Comment 1: STOP EINSTAND
# Comment 2: raus auf null
# Comment 3: greife ernut an
# short
# 9258
# 9265
# 2014-02-06T15:52:12+0000
# DAX SHORT 9265 STOP 6 PK
# Comment 1: 9251 TVK !
# Comment 2: rest auf einstand !
# Comment 3: besser als nix
# Comment 4: 9247 TVK !
# Comment 5: achtung ! reise nach unten kann zuende sein
# Comment 6: rest raus auf einstand !!!!!
# Comment 7: schnelle 18 PK
# short
# 9265
# 9271
# 2014-02-06T12:13:15+0000
# DAX SHORT 9220 STOP 5 PK
# Comment 1: 9207 TVK ! Stop einstand !
# Comment 2: 9197 TVK
# Comment 3: 9185 TVK !
# Comment 4: 9165 TVK !!! Schade !! hätte gerne meine 9020 !!!!
# short
# 9220
# 9225
# 2014-02-06T11:28:11+0000
# DAX SHORT 9228 STOP 8 PK
# Comment 1: mini size
# Comment 2: ich verlasse den trade hier mal lieber
# Comment 3: raus zu 9224 ! man muss nicht überall dabei sein ! hossa wäre viel früher raus aber dann kam der rutsch ! war bei 9225 schon am drücken,text vorbereitet und zack
# short
# 9228
# 9236
# 2014-02-06T10:19:30+0000
# DAX SHORT 9220 STOP 12 PK
# Comment 1: - 12 PK !
# Comment 2: mir war das level nach unten zuwenig um einen TVK zu machen
# short
# 9220
# 9232
# 2014-02-06T09:54:52+0000
# DAX SHORT 9220 STOP 5 PK
# Comment 1: 9205 TVK !!
# Comment 2: stop einstand
# Comment 3: Trade Ende + 15 PK
# short
# 9220
# 9225
# 2014-02-06T09:22:16+0000
# DAX LONG 9169 STOP 10 PK
# Comment 1: Ziel 9220 !
# Comment 2: STOP EINSTAND !
# Comment 3: 9206 DIREKT NEN TVK !
# Comment 4: 9215 TVK
# Comment 5: 9220 !!! ZIEL ERREICHT !!!!!!
# Comment 6: 9230 TVK !
# Comment 7: rest raus zum einstand !
# Comment 8: mit 4 pk slippage ! warum auch immer
# Comment 9: + 61 PK
# long
# 9169
# 9159
# 2014-02-05T14:42:26+0000
# DAX SHORT 9140 STOP 9152
# Comment 1: umkehr im 5 M
# Comment 2: trotzdem bin ich vorsichtig
# Comment 3: 9130 TVK ! Stop einstand !
# Comment 4: 9122 TVK ! so ! danke dax
# Comment 5: 9120 grosser teil weg !!!! gleich news in 3 min
# Comment 6: Trade ende ! + 20 PK
# short
# 9140
# 9152
# 2014-02-05T09:43:24+0000
# DAX SHORT 9145 STOP 7 PK den kleinen Versuch starte ich noch... mini size....
# Comment 1: stop einstand
# Comment 2: 9130 TVK
# Comment 3: 9121 TVK
# Comment 4: 9107 TVK
# Comment 5: 9095 TVK :-)
# Comment 6: rest raus auf einstand ! + 50 PK !
# short
# 9145
# 9152
# 2014-02-05T08:37:49+0000
# DAX SHORT 9124 STOP 9134
# Comment 1: -10 PK
# short
# 9124
# 9134
# 2014-02-04T12:58:05+0000
# DAX LONG 9090 STOP 10 PK
# Comment 1: stop auf einstand
# Comment 2: 9110 TVK
# Comment 3: 9121 TVK
# Comment 4: 9130 TVK
# Comment 5: nun renn !
# Comment 6: 9150 TVK ! mini rest bleibt mit angegebenem ziel
# Comment 7: Trade Ende ! + 60 PK
# long
# 9090
# 9080
# 2014-02-04T08:36:46+0000
# DAX LONG 9100 STOP 10 PK
# Comment 1: Stop Einstand !
# Comment 2: 9124 TVK
# Comment 3: 9135 TVK
# Comment 4: ziel 9170/9180 bleibt !
# Comment 5: Trade ende ! + 35 PK
# long
# 9100
# 9090
# 2014-02-04T08:17:47+0000
# DAX LONG 9096 STOP 5 PK
# Comment 1: kleiner versuch
# Comment 2: mal long zu gehen
# Comment 3: wird aber nix denke ich
# Comment 4: 0.2 pk der stop gehalten
# Comment 5: - 5 PK
# long
# 9096
# 9091
# 2014-02-03T16:04:12+0000
# DAX SHORT 9229 STOP 9235
# Comment 1: stop einstand
# Comment 2: 9206 tvk
# Comment 3: 9175 tvk
# Comment 4: 9160 TVK !
# Comment 5: rest bleibt overnight falls nicht der dax über 9200/9210 geht
# Comment 6: 9114 TVK
# Comment 7: 115 PK ! rest rennt :-)
# short
# 9229
# 9235
# 2014-02-03T15:01:46+0000
# DAX SHORT 9248 STOP 10 PK
# Comment 1: 9210 TVK
# Comment 2: stop einstand
# Comment 3: 9185 TVK
# Comment 4: + 63 PK
# short
# 9248
# 9258
# 2014-01-31T09:16:52+0000
# Dax Short 9300 stop 9310
# Comment 1: Stop Einstand
# Comment 2: 9260 tvk
# Comment 3: 9230 tvk
# Comment 4: 9200 tvk
# Comment 5: 😁😁😁
# Comment 6: 9170 TVK
# Comment 7: FLAT ! + 130 PK !
# short
# 9300
# 9310
# 2014-01-30T13:36:52+0000
# DAX LONG 9317 STOP 10 PK
# Comment 1: STOP EINSTAND
# Comment 2: :-)
# Comment 3: 9355 TVK
# Comment 4: 9383 TVK !!!! läuft.......
# Comment 5: 9413 TVK !!!!! der rest ist bonus !!! es kann sein das hier nun ermüdungen kommen.....
# Comment 6: rest bleibt mit ca. 9430-9450 an board.....
# long
# 9317
# 9307
# 2014-01-30T13:31:46+0000
# DAX SHORT 9305 STOP 10 PK Mini size
# Comment 1: - 10 KP
# Comment 2: wird wohl nun ein long dy
# short
# 9305
# 9315
# 2014-01-28T10:41:32+0000
# Dax Short 9420 stop 9430
# Comment 1: Dafür bewegst du dich gleich :-)
# Comment 2: Sorry dafür mein Fehler!
# Comment 3: Kein Problem :-)
# Comment 4: 9390 tvk Rest stop Einstand
# Comment 5: 9380 tvk
# Comment 6: 9350 tvk
# Comment 7: mini rest raus zum einstand ! + 70 PK :-)
# short
# 9420
# 9430
# 2014-01-24T13:51:30+0000
# DAX SHORT 9526 STOP 10 PK
# Comment 1: 9520 kann ende sein !
# Comment 2: stop einstand !
# Comment 3: 9516 TVK
# Comment 4: 9503 TVK !
# Comment 5: 9472 TVK :-)
# Comment 6: 9466 TVK
# Comment 7: 9440 FLAT !!!!!! + 86 PK !!!!!!!! soll reichen !
# short
# 9526
# 9536
# 2014-01-24T12:09:08+0000
# DAX LONG 9499 STOP 5 PK
# Comment 1: 9518 TVK
# Comment 2: STOP EINSTAND
# Comment 3: 9535 TVK
# Comment 4: FLAT ! + 36 PK
# long
# 9499
# 9494
# 2014-01-24T11:51:29+0000
# DAX LONG 9499 STOP 15 PK MINI SIZE "!!!!"!"! RISKY
# Comment 1: stop einstand !
# Comment 2: flat auf einstand
# long
# 9499
# 9484
# 2014-01-24T10:23:36+0000
# DAX SHORT 9592 STOP 10 PK
# Comment 1: 9567 TVK
# Comment 2: stop einstand
# Comment 3: 9556 TVK
# Comment 4: 9536 TVK
# Comment 5: zur korrektur : 9592 nicht 5952
# Comment 6: 9500 TVK
# Comment 7: 9492 FLAT !!!!!! + 100 PK !!!
# short
# 9592
# 9602
# 2014-01-24T10:20:34+0000
# DAX LONG 9595 STOP 7 PK
# Comment 1: 9593 händisch raus
# Comment 2: wie im tageasthread angegeben
# long
# 9595
# 9588
# 2014-01-24T09:33:46+0000
# DAX LONG 9592 STOP 9580 MINI SIZE
# Comment 1: Stop einstand !
# Comment 2: 9622 TVK :-) !
# Comment 3: rest raus einstand
# Comment 4: +30 PK
# long
# 9592
# 9580
# 2014-01-23T15:17:02+0000
# DAX LONG 9615 STOP 9608
# Comment 1: STOP EINSTAND !
# Comment 2: TVK 9630
# Comment 3: rest raus auf eintand
# long
# 9615
# 9608
# 2014-01-23T15:11:44+0000
# DAX LONG 9619 STOP 6 PK
# Comment 1: -6 PK
# long
# 9619
# 9613
# 2014-01-23T12:04:03+0000
# DAX LONG 9676 STOP 10 PK
# Comment 1: stop einstand
# Comment 2: bin schnell auf einstand weil es kann auch tiefer gehen
# Comment 3: entry war 9677
# Comment 4: in der eile vertippt
# Comment 5: TVK bei 9700
# Comment 6: REST FLAT
# long
# 9676
# 9666
# 2014-01-22T11:09:25+0000
# Dax Long 9683 stop 9673
# Comment 1: Stop Einstand
# Comment 2: 9713 tvk. Ins Momentum rein
# Comment 3: 9723 tvk
# Comment 4: 9740 TVK :-)
# Comment 5: stop hoch auf 9705
# Comment 6: 9653 TVK :-)
# Comment 7: rest raus 9705
# Comment 8: immerhin 70 PK !
# long
# 9683
# 9673
# 2014-01-22T08:13:58+0000
# DAX SHORT 9760 STOP 7 PK
# Comment 1: TP BEI 9730 / 9700
# Comment 2: STOP EINSTAND
# Comment 3: 9740 doch schonmal TP
# Comment 4: 9690 TP :-)
# Comment 5: 9610 TP ! :-)
# Comment 6: +150 PK !
# Comment 7: :-)
# Comment 8: diesmal hats was gebracht den stop nicht nachzuziehen
# Comment 9: rest steht auf 9560 :-)
# Comment 10: FLAT zu 9560 !!! + 200 PK :-)
# short
# 9760
# 9767
# 2014-01-21T14:12:08+0000
# DAX SHORT 9787 STOP 20 PK
# Comment 1: soviele likes ? oha ! das wird dann gefährlich
# Comment 2: Stop einstand !
# Comment 3: 9764 TVK
# Comment 4: 9735 TVK :-)
# Comment 5: 9727 nun 80 % glatt ! 60 pk in 1 Stunde ! YEPPA
# Comment 6: und das in die "falsche, ach wie kann man nur im long markt shorten, Richtung " :-)
# Comment 7: 9717 90% flat !!!
# Comment 8: 70 leckere punkte
# Comment 9: 9690 flat ! + 97 PK
# short
# 9787
# 9807
# 2014-01-21T09:31:30+0000
# DAX SHORT 9745 STOP 8 PK
# Comment 1: kleine size
# Comment 2: -8 pk ! zum glück kleine size ! kleine size sind 0.2 - 0-5 % aufs depot !
# short
# 9745
# 9753
# 2014-01-20T10:56:50+0000
# DAX SHORT 9722 STOP 9728
# Comment 1: kleine size und kleiner versuch
# Comment 2: mini posi usgestoppt......
# Comment 3: -6 pk
# short
# 9722
# 9728
# 2014-01-20T08:31:59+0000
# DAX LONG 9690 STOP 10 PK
# Comment 1: stop einstand
# Comment 2: 9715 TVK 1/2
# Comment 3: 9725 TVK ! hab nun noch nen rest den ich laufen lasse mit ziel 9790.....
# Comment 4: Bleibt Overnight
# Comment 5: lauf forrest
# Comment 6: 9759 3/4 weg....
# Comment 7: Stop auf 9730 nachgezogen
# Comment 8: 9790 erreicht ! TRADE HIER KOMPLETT GESCHLOSSEN ! + 100 PK !
# long
# 9690
# 9680
# 2014-01-15T13:34:24+0000
# DAX SHORT 9676 STOP 5 PK
# Comment 1: 9661 TVK
# Comment 2: rest raus zu 9681
# short
# 9676
# 9681
# 2014-01-15T08:09:08+0000
# DAX LONG 9590 STOP 10 PK
# Comment 1: dojis im 5M chart... hmmmmmmmmmm
# Comment 2: trade muss jetzt anspringen sonst wird der nix !
# Comment 3: stop einstand !
# Comment 4: 9620 TVK :-)
# Comment 5: das ging aber fix :-)
# Comment 6: 9640 TVK
# Comment 7: 50 PK am morgen vertreiben kummer und sorgen !
# Comment 8: 9655 TVK
# Comment 9: 9670
# Comment 10: nur noch mini rest am start
# Comment 11: 9685 FLAT ! + 95 PK !
# long
# 9590
# 9580
# 2014-01-14T12:22:24+0000
# DAX SHORT 9460 STOP 7 PK mini mini size
# Comment 1: -7 pk !
# short
# 9460
# 9467
# 2014-01-14T10:29:01+0000
# DAX SHORT 9450 STOP 12 PK !
# Comment 1: ich steige gleich händisch aus
# Comment 2: wollte raus aber trade lief langsam an ! schade drum ! ich mache erstmal nix mehr
# short
# 9450
# 9462
# 2014-01-13T09:14:04+0000
# DAX LONG 9495 STOP 10 PK
# Comment 1: 9515 TVK
# Comment 2: Stop auf einstand nun
# Comment 3: rest flat auf einstand
# long
# 9495
# 9485
# 2014-01-10T15:01:25+0000
# DAX SHORT 9470 STOP 10 PK
# Comment 1: STOP EINSTAND !!!
# Comment 2: 9452 TVK
# Comment 3: rest rausa auf einstand !
# short
# 9470
# 9480
# 2014-01-10T14:18:52+0000
# DAX LONG 9475 STOP 10 PK
# Comment 1: flat zum einstand !!!
# Comment 2: 0 pk
# Comment 3: trade ende
# long
# 9475
# 9465
# 2014-01-10T13:34:57+0000
# DAX SHORT 9488 STOP 15 PK
# Comment 1: 9455 TVK
# Comment 2: stop einstand
# Comment 3: 33 PK ! trade ende !!!!
# short
# 9488
# 9503
# 2014-01-10T09:50:56+0000
# DAX SHORT 9474 STOP 9490
# Comment 1: -16 PK !
# short
# 9474
# 9490
# 2014-01-08T15:28:51+0000
# DAX SHORT 9497 STOP 8 PK
# Comment 1: Stop auf einstand !
# Comment 2: 9480 1 TVK !
# Comment 3: rest raus auf einstand ! + 17 PK !!!
# short
# 9497
# 9505
# 2014-01-07T15:53:19+0000
# DAX SHORT 9515 STOP 9535
# Comment 1: 9487 TVK !
# Comment 2: stop einstand !
# Comment 3: REST ging auf einstand leider raus ! wegen einem PUNKT
# short
# 9515
# 9535
# 2014-01-07T08:18:10+0000
# DAX LONG 9428 STOP 10 PK
# Comment 1: -10 PK
# Comment 2: stop um 1 pk geholt und nach oben :-(
# long
# 9428
# 9418

# %%
import numpy as np
einstand_re = re.compile(r'(?:^|\s|$)einstand(?:^|\s|$)', re.IGNORECASE)
tvk_re = re.compile(r'(?:^|\s|$)(tvk|tp|[0-9](st|nd|rd|th))(?:^|\s|$)', re.IGNORECASE)
index_re = re.compile(r'[0-9]{4,5}')
def get_tradeout(row, num_tvk):
    einstand = False
    tvks = []
    for com in row['comments']['data']:
        if einstand_re.findall(com['message']):
            einstand = True
        if tvk_re.findall(com['message']):
            ix = index_re.search(com['message'])
            if ix:
                tvks.append(int(ix.group()))
                einstand = True
                
    tvks.append(row['in'] if einstand else row['stop'])
    return np.mean(tvks[:min([num_tvk, len(tvks)])])
                      
db['out'] = db.apply(lambda row: get_tradeout(row, 2), axis=1)
db['pl'] = db.apply(lambda row: row['out'] - row['in'] if row['longshort'] == 'long' else row['in'] - row['out'], axis=1)
#add commission
db['pl'] = db['pl'].apply(lambda _: -2 if _ <= 0 else -4)

db.sort_index(ascending=True, inplace=True)
jan13 = db.ix['2013':'2014']
jan13['pl_cs'] = jan13['pl'].cumsum()
jan13[['pl', 'pl_cs']].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-248-7c9d6e00ede7> in <module>()
#      27         return -4
#      28
# ---> 29 db['pl'] = db['pl'].apply(add_commission, axis=1)
#      30
#      31 db.sort_index(ascending=True, inplace=True)
#
# /Users/bertrammuller/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2445             values = lib.map_infer(values, lib.Timestamp)
#    2446
# -> 2447         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2448         if isinstance(mapped[0], Series):
#    2449             from pandas.core.frame import DataFrame
#
# /Users/bertrammuller/anaconda/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:41822)()
#
# /Users/bertrammuller/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in <lambda>(x)
#    2434
#    2435         if kwds or args and not isinstance(func, np.ufunc):
# -> 2436             f = lambda x: func(x, *args, **kwds)
#    2437         else:
#    2438             f = func
#
# TypeError: add_commission() got an unexpected keyword argument 'axis'

# %%
for i in range(-200, -100):
    print_msg(db.iloc[i])
    print db.iloc[i]['pl']
    print ""
# Out:
# 2013-04-04T10:17:57+0000
# DAX LONG 7903 STOP 7893
# Comment 1: 7911 1st
# Comment 2: entweder läuft der jetzt an oder fällt in sich zusammen
# Comment 3: stop einstand
# Comment 4: 7927 2nd
# Comment 5: wenn der markt normal bleibt wären 8000 - 8010 das ziel !
# Comment 6: + 24 PK trade ende !
# 16.0
#
# 2013-04-04T10:39:02+0000
# DAX SHORT 7909 STOP 7914
# Comment 1: -5 pk
# -5.0
#
# 2013-04-05T11:28:53+0000
# DAX LONG 7680 STOP 7675
# Comment 1: -5 pk
# -5.0
#
# 2013-04-05T11:30:40+0000
# DAX LONG 7675 STOP 7670
# Comment 1: 7685 1st
# Comment 2: 7694 2nd
# Comment 3: 7700 3rd
# Comment 4: flat + 25
# 14.5
#
# 2013-04-05T13:34:37+0000
# DAX LONG 7653 STOP 6749
# Comment 1: 7663 1st
# Comment 2: rest einstand !!!
# Comment 3: rest raus einstand
# 5.0
#
# 2013-04-09T07:54:47+0000
# DAX SHORT 7699 STOP 7707
# Comment 1: - 8 PK
# -8.0
#
# 2013-04-10T13:25:48+0000
# DAX SHORT 7728 STOP 7732
# Comment 1: -4 pk !
# -4.0
#
# 2013-04-10T13:30:37+0000
# DAX SHORT 7726 STOP 7735 !
# Comment 1: -9 pk ! WOW
# -9.0
#
# 2013-04-10T15:25:52+0000
# DAX SHORT 7818 STOP 7823
# Comment 1: 7810 1st
# Comment 2: stop einstand
# Comment 3: rest raus zumm einstand !
# 4.0
#
# 2013-04-11T13:21:41+0000
# DAX SHORT 7840 STOP 7847
# Comment 1: 7828 1st ! get dch ! lol
# Comment 2: stop einstand
# Comment 3: 7822 2nd !
# Comment 4: + 18 pk ! TradeEnde !
# Comment 5: Super, bei nur 12pk schönen Feierabend
# 15.0
#
# 2013-04-11T14:11:44+0000
# DAX SHORT 7841 STOP 7847
# Comment 1: 7833 1st
# Comment 2: stop einstand ! VORSICHT ! Dax kann eventuell hoch !
# Comment 3: ab hier !
# Comment 4: 8 pk ! trade ende !
# 4.0
#
# 2013-04-12T09:12:36+0000
# DAX SHORT 7790 STOP 7800
# Comment 1: 7753 1st !
# Comment 2: stop einstand
# Comment 3: 7745 2nd
# Comment 4: 7735 3rd
# Comment 5: 7711 steht noch einer ! los
# 41.0
#
# 2013-04-12T09:43:14+0000
# DAX LONG 7758 STOP 7751
# Comment 1: zielel 7772 , 7780 7800
# Comment 2: sotp einstand
# Comment 3: 7772 1st
# Comment 4: 7780 2nd
# Comment 5: Passender DAX LONG ! STOP is KNOCK : DX6L4D
# Comment 6: zu 0,41 mal rein
# Comment 7: Trade ende !
# Comment 8: ü 22 pips
# Comment 9: + 22pips
# Comment 10: raus zu 0,30
# 18.0
#
# 2013-04-15T08:00:27+0000
# DAX SHORT 7742 STOP 7752
# Comment 1: 7732 1st
# Comment 2: 7720 2nd
# Comment 3: Stop einstand
# Comment 4: 7711 3rd...
# Comment 5: 7672 4th
# Comment 6: 7662 5th !
# 16.0
#
# 2013-04-15T09:59:44+0000
# DAX LONG 7665 STOP 7658
# Comment 1: riskant ! kleine size nehmen !
# Comment 2: -7 PK
# Comment 3: 13pk
# Comment 4: OLIVER TRAUE !!! NICHT IN TRADES POSTEN !!!!
# -7.0
#
# 2013-04-15T10:14:06+0000
# DAX LONG 7654 STOP 7650
# Comment 1: 7671 1st
# Comment 2: sotp einstand
# Comment 3: Derivat für alle longer
# Comment 4: 7680 2nd
# Comment 5: 7690 3rd
# Comment 6: 7720 4th !
# 21.5
#
# 2013-04-16T08:08:16+0000
# DAX LONG 7662 STOP 7654
# Comment 1: - 8 PK
# -8.0
#
# 2013-04-16T12:28:30+0000
# DAX SHORT 7714 STOP 7718
# Comment 1: wenn er unter die 7712 kommt sollte es rutschen !!! short ist der falsche weg !!!! ich shorte den eventuellen rücksetzer !!! es fehlt mir meine 7790
# Comment 2: ich verlasse evenuell diesen trade
# Comment 3: mal sehen
# Comment 4: raus zum einstand
# Comment 5: trade ende
# 0.0
#
# 2013-04-17T07:12:29+0000
# DAX SHORT 7712 STOP 7722
# Comment 1: Stop einstand
# Comment 2: Reentry
# Comment 3: Stop 7714
# Comment 4: stop einstand
# Comment 5: 7700 1st
# Comment 6: 7686 2nd
# Comment 7: 7679 3rd
# Comment 8: 7662 4th
# Comment 9: 7522 5th !!!!! 190 PK !!!!!!!!!!! FEIERABEND !
# Comment 10: 7482 FLAT!!!! + 230 PK !!!!!!!!!!!!!!!!!!
# 19.0
#
# 2013-04-17T07:18:14+0000
# DAX LONG 7709 STOP 7704
# Comment 1: -5 PK
# -5.0
#
# 2013-04-17T11:00:40+0000
# Dax Long 7550 Stop 7540
# Comment 1: Vorsicht !
# Comment 2: 7561 1st
# Comment 3: flat ! 0 runde
# 5.5
#
# 2013-04-18T07:16:58+0000
# DAX LONG 7500 STOP 7495
# Comment 1: Risk
# Comment 2: 7527 1st
# Comment 3: 7535 2nd !
# Comment 4: stop einstand
# Comment 5: 7550 3rd
# 31.0
#
# 2013-04-22T12:59:14+0000
# DAX LONG 7497 STOP 7492
# Comment 1: 7507 1st
# Comment 2: 7515 2nd !
# Comment 3: Stop Einstand !
# Comment 4: rest raus auf eisntand ! + 18 PK !
# 14.0
#
# 2013-04-23T07:52:38+0000
# DAX LONG 7462 STOP 7460 !
# Comment 1: flat ! - 2 PK
# -2.0
#
# 2013-04-23T14:24:15+0000
# DAX SHORT 7649 STOP 7655
# Comment 1: 7637 1st
# Comment 2: rest raus zum einstand !!!!!! das wird nix !!!
# Comment 3: + 13 pk
# 6.0
#
# 2013-04-24T07:43:17+0000
# DAX SHORT 7694 STOP 7705
# Comment 1: stop auf 7706
# Comment 2: 7682 1st
# Comment 3: 7673 2nd
# Comment 4: stop eisntand
# Comment 5: 7667 3rd
# 16.5
#
# 2013-04-24T14:48:12+0000
# DAX SHORT 7761 STOP 7775 !
# Comment 1: 7750 1st
# Comment 2: 7745 2nd ! rest auf einstand !!!!!!
# Comment 3: + 16 PK ! Trade ende !
# 13.5
#
# 2013-04-25T08:30:01+0000
# DAX LONG 7748 STOP 7740
# Comment 1: 7765 1st
# Comment 2: rest stop einstand
# Comment 3: + 17 PK
# 8.5
#
# 2013-04-26T12:59:18+0000
# DAX SHORT 7800 STOP 7806
# Comment 1: risky trade !
# Comment 2: bin nur mit mini size drin ! sprich 5 euro pro punkt ! wäre ein loss von 30 euro :-) keine lust was liegen zu lassen !
# Comment 3: könnte auch bis 7840 hoch um dann nochmal runter zu gehen ! denke eher wir haben eine seitwärts formation !
# Comment 4: mal sehen
# Comment 5: -6 PK
# -6.0
#
# 2013-04-30T09:15:04+0000
# DAX SHORT 7937 STOP 7947
# Comment 1: 7923 1st !
# Comment 2: stop runter auf 7944
# Comment 3: STOP auf einstand ! nix wird abgegeben !!!
# Comment 4: 7918 2nd !
# Comment 5: 7913 3rd
# Comment 6: 7907 4th !
# Comment 7: letzter bleibt entweder bis auf eisntand oder bis gap close kassa !
# Comment 8: 7894 4,5 gedeckt ! mini rest bleibt !
# 16.5
#
# 2013-04-30T12:07:57+0000
# DAX LONG 7912 STOP 7904
# Comment 1: stop eisntand
# Comment 2: 7920 1st
# Comment 3: 7928 2nd :-) !
# Comment 4: 7935 3rd
# Comment 5: rest raus auf einstand ! + 23 PK !
# 12.0
#
# 2013-05-02T13:40:50+0000
# DAX SHORT 7943 STOP 7953
# Comment 1: -10 PK
# -10.0
#
# 2013-05-02T15:12:41+0000
# DAX SHORT 7964 STOP 7974 !
# Comment 1: - 10 PK !
# -10.0
#
# 2013-05-08T11:12:58+0000
# DAX SHORT 8237 STOP 8243 ! VORSICHT !!! MINI SIZE !
# Comment 1: sotp einstand
# Comment 2: 8219 1st !
# Comment 3: 8216 2nd
# Comment 4: 8209 3rd !
# Comment 5: + 28 PK !
# 19.5
#
# 2013-05-10T07:23:19+0000
# DAX SHORT 8330 STOP 8340 ! MEGA VORSICHT !!!!! SAU GEFÄHLRICH !
# Comment 1: - 10 PK !
# -10.0
#
# 2013-05-14T13:46:03+0000
# Dax Short 8311 stop 8325
# Comment 1: -14 pk
# -14.0
#
# 2013-05-22T13:52:03+0000
# DAX SHORT 8477 STOP 8485 ! VORSICHT !
# Comment 1: stop auf 87
# Comment 2: eventuell dreht er erst vor der 8500 ! drüber is nix mehr so wirklich mit short
# Comment 3: -10 pk
# -8.0
#
# 2013-05-23T12:33:50+0000
# DAX LONG 8317 STOP 8307
# Comment 1: 8307 exit ! - 10 pk
# -10.0
#
# 2013-05-23T13:54:05+0000
# DAX LONG 8294 STOP 8284
# Comment 1: stop auf einstand !
# Comment 2: 8304 1st
# Comment 3: rest raus auf einstand !!!
# 5.0
#
# 2013-05-23T14:02:58+0000
# DAX LONG 8296 STOP 8284
# Comment 1: Stop auf Einstand !
# Comment 2: 8331 1st
# Comment 3: erstes ziel war 8330 ! next is 8350 !
# Comment 4: http://www.youtube.com/watch?v=uc2UEfWjvo8
# Comment 5: Stop auf 8306 nachziehen
# Comment 6: + 35 PK !
# 17.5
#
# 2013-05-24T13:24:12+0000
# DAX LONG 8297 STOP 8287
# Comment 1: - 10 PK !
# -10.0
#
# 2013-05-28T07:03:47+0000
# DAX SHORT 8429 STOP 8439
# Comment 1: - 10 PK
# -10.0
#
# 2013-05-28T07:12:26+0000
# DAX SHORT 8456 STOP 8465
# Comment 1: - 9 PK !
# -9.0
#
# 2013-05-28T11:03:27+0000
# DAX LONG 8469 STOP 8465
# Comment 1: 8480 1st
# Comment 2: stop einstand !
# Comment 3: 8482 2nd
# 12.0
#
# 2013-05-29T11:01:10+0000
# DAX LONG 8340 STOP 8330 !
# Comment 1: - 10 pk !
# -10.0
#
# 2013-05-29T11:10:01+0000
# DAX LONG 8335 STOP 8325
# Comment 1: 8346 1st
# Comment 2: 8361 2nd
# Comment 3: STOP EINSTAND !
# Comment 4: 8368 3rd
# Comment 5: rest raus auf einstand
# Comment 6: + 33 PK....
# 18.5
#
# 2013-05-29T11:38:15+0000
# DAX SHORT 8361 STOP 8374
# Comment 1: 8346 1st
# Comment 2: 8340 2nd
# Comment 3: 8334 3rd
# Comment 4: 8327 4th
# Comment 5: stop auf einstand
# Comment 6: + 34 PK !
# Comment 7: flat
# 18.0
#
# 2013-05-29T15:00:45+0000
# DAX SHORT 8330 STOP 8345 !
# Comment 1: 8320 1st
# Comment 2: stop eintsand
# Comment 3: + 10 pk
# 5.0
#
# 2013-05-30T09:56:44+0000
# DAX SHORT 8357 STOP 8367
# Comment 1: 8350 1st
# Comment 2: 8346 2nd
# Comment 3: rest raus !!!!! 0 runde !!!!
# 9.0
#
# 2013-05-30T11:27:57+0000
# DAX SHORT 8405 STOP 8415 ! vorsicht !
# Comment 1: -10 pk !
# -10.0
#
# 2013-05-30T12:37:29+0000
# DAX SHORT 8403 STOP 8410 !
# Comment 1: 8378 1st
# Comment 2: stop auf einstand !
# Comment 3: 8363 3rd
# Comment 4: + 40 PK !
# Comment 5: trade ende
# 32.5
# 2013-06-03T08:43:16+0000
# DAX LONG 8240 STOP 8230
# Comment 1: 8269 1st
# Comment 2: Stop Einstand
# Comment 3: 8277 2nd
# Comment 4: 8295 3rd
# Comment 5: 8315 4th ! rest bleibt bis 8340/8350
# Comment 6: 8340 flat ! + 100 PK .... Feierabend ? :-)
# 33.0
#
# 2013-06-03T13:11:07+0000
# DAX LONG 8350 STOP 8345
# Comment 1: stop einstand und 8363 1 tvk
# Comment 2: + 13 pk !
# Comment 3: trade ende !
# 6.5
#
# 2013-06-04T07:16:17+0000
# DAX SHORT 8374 STOP 8384
# Comment 1: 8350 1st
# Comment 2: stop auf einstand !
# Comment 3: 8345 2nd! ziele bleiben 8335 8325 8300 oder sogar 8275
# Comment 4: 8331 3rd
# Comment 5: 8318 4th
# Comment 6: 8300 5th. Letter bleibt bis 8275 an Board.
# Comment 7: 8278 flat !! + 96
# 33.5
#
# 2013-06-04T09:04:08+0000
# DAX LONG 8324 STOP 8314 !
# Comment 1: - 10 pk !
# -10.0
#
# 2013-06-04T09:51:48+0000
# DAX LONG 8315 STOP 8308 !
# Comment 1: 8330 1st
# Comment 2: stop auf einstand !!! na endlich !
# Comment 3: Rest raus zum Einstand
# 7.5
#
# 2013-06-04T15:42:57+0000
# Dax long 8295 stop 8287
# Comment 1: 8305 1st
# Comment 2: 0 runde
# 5.0
#
# 2013-06-04T16:22:17+0000
# Dax Long 8284 stop 8270. drunter riskant !
# Comment 1: 8294 1st
# 5.0
#
# 2013-06-17T12:50:05+0000
# DAX SHORT 8229 STOP 8242
# Comment 1: - 13 PK !
# -13.0
#
# 2013-06-18T07:20:24+0000
# DAX SHORT 8179 STOP 8187
# Comment 1: - - 8 PK !
# -8.0
#
# 2013-06-18T07:51:31+0000
# DAX SHORT 8213 STOP 8223
# Comment 1: 8195 1st
# Comment 2: stop einstand ! save is save
# Comment 3: rest raus zum einstand !
# Comment 4: + 18 PK !
# 9.0
#
# 2013-06-18T08:24:19+0000
# DAX SHORT 8210 STOP 8220 !
# Comment 1: 8200 1st
# Comment 2: 8180 2nd
# Comment 3: stop einstand für den rest
# Comment 4: rest raus zum einstand ! + 30 PK
# 20.0
#
# 2013-06-18T10:36:00+0000
# DAX SHORT 8220 STOP 8235
# Comment 1: 8208 1st.
# Comment 2: 8203 2nd
# Comment 3: + 17 - 15 = 2
# 8.5
#
# 2013-06-19T06:56:37+0000
# Dax Short 8260 Stop 8275
# Comment 1: 8218 1st.
# Comment 2: Stop Einstand 😁
# Comment 3: 8165 2nd
# Comment 4: Rest raus auf Einstand !
# Comment 5: + 95 pk
# 47.5
#
# 2013-06-21T15:35:45+0000
# Dax Long 7774 stop 7740
# Comment 1: 7790 1st
# Comment 2: 7805 2nd
# Comment 3: Stop Einstand !
# Comment 4: 7825 3rd
# Comment 5: 7850 4th
# 23.5
#
# 2013-06-27T12:49:58+0000
# DAX SHORT 7960 STOP 7965
# Comment 1: -5 PK
# -5.0
#
# 2013-06-27T14:58:38+0000
# DAX SHORT 8018 STOP 8028 !
# Comment 1: scalp
# Comment 2: 8006 1st
# Comment 3: stop einstand !
# Comment 4: 8003 2nd
# Comment 5: 7994 3rd !
# Comment 6: 7974 4th
# Comment 7: Rest raus zum Einstand
# 13.5
#
# 2013-07-01T12:32:43+0000
# DAX LONG 7975 STOP 7967
# Comment 1: 7982 1st
# Comment 2: 7993 2nd
# Comment 3: stop einstand !
# Comment 4: 8002 3rd !
# Comment 5: 8015 4th
# Comment 6: Rest raus auf Einstand ! + 40 Pk.
# 12.5
#
# 2013-07-02T07:37:45+0000
# DAX LONG 7949 STOP 7938
# Comment 1: -11 PK
# -11.0
#
# 2013-07-03T13:58:32+0000
# DAX SHORT 7796 STOP 7806
# Comment 1: 7786 1st
# Comment 2: 7770 2nd
# Comment 3: stop einstand
# Comment 4: + 26 PK ! Trade ende ! rest raus einstand !
# 18.0
#
# 2013-07-08T07:01:53+0000
# DAX SHORT 7889 STOP 7902
# Comment 1: 7875 1st
# Comment 2: 0 runde !
# 7.0
#
# 2013-07-08T07:23:16+0000
# DAX SHORT 7900 STOP 7910 !
# Comment 1: stop auf einstand !!!!
# Comment 2: 7890 1st !
# Comment 3: + 10 pk !
# Comment 4: rest raus auf einstand
# 5.0
#
# 2013-07-09T09:05:22+0000
# DAX SHORT 8051 STOP 8060
# Comment 1: - 9pk
# -9.0
#
# 2013-07-12T12:55:20+0000
# DAX SHORT 8225 STOP 8248
# Comment 1: 8204 1st
# Comment 2: 8195 2nd
# Comment 3: stop einstand !
# Comment 4: Raus zum Einstand .
# 25.5
#
# 2013-07-16T09:31:19+0000
# DAX SHORT 8219 STOP 8240 !
# Comment 1: Derivat dazu ! WKN : DX7SXA KURS : 0,70 STOP 0,40
# Comment 2: Stopsenkung auf 8224
# Comment 3: 1. Tvk: 8195 (Derivat 0,90)
# Comment 4: Derivat stop Einstand !
# Comment 5: Stop Einstand
# Comment 6: Ausgestoppt. + 24 pk / + 30%
# 0.0
#
# 2013-07-18T12:44:52+0000
# DAX SHORT 8283 STOP 8293
# Comment 1: NICHT IN TRADES POSTEN BITTE ! DANKE !
# Comment 2: - 10 PK !
# -10.0
#
# 2013-07-18T13:07:31+0000
# DAX SHORT 8290 STOP 8297
# Comment 1: stop 8305
# Comment 2: -15 pk !
# -7.0
#
# 2013-08-05T12:11:48+0000
# DAX SHORT 8395 STOP 8408
# Comment 1: 8383 1st
# Comment 2: 8380 2nd
# Comment 3: stop einstand.....
# Comment 4: 8370 3rd......
# Comment 5: +25. Trade Ende
# 13.5
#
# 2013-08-07T13:04:54+0000
# DAX SHORT 8266 STOP 8278
# Comment 1: Orkan Kuyas DX8ZD0
#
# vor 26 Minuten · Gefällt mir · 1 da stand er kurs bei 0,44
# Comment 2: 8245 tvk
# Comment 3: 0,64 tvk
# Comment 4: rest stop einstand
# Comment 5: rest raus auf einstand
# Comment 6: + 21 PK
# 10.5
#
# 2013-08-12T09:03:29+0000
# DAX SHORT 8270 STOP 8290 !
# Comment 1: 8242 1st
# Comment 2: Stop auf Einstand
# Comment 3: + 28 PK !
# Comment 4: rest raus auf einstand
# 14.0
#
# 2013-08-12T12:26:10+0000
# DAX SHORT 8308 STOP 8318
# Comment 1: - 10 pk
# -10.0
#
# 2013-08-13T07:32:21+0000
# DAX SHORT 8440 STOP 8450 (RISK) !
# Comment 1: passendes Derivat zu dem short : WKN : DX8Z31
# Comment 2: Kurs 0,30
# Comment 3: 8418 1st
# Comment 4: 8408 2nd
# Comment 5: stop einstand !!!!!!!!!!!
# Comment 6: 0,50 im Derivat !
# Comment 7: tvk
# Comment 8: 8397 3rd
# Comment 9: 62 Cent !!! 100 %%% !!! YES !!!!
# Comment 10: tradeende +43Punkte / +100%
# 27.0
#
# 2013-08-16T09:26:25+0000
# DAX SHORT 8361 STOP 8371
# Comment 1: 8345 1st
# Comment 2: 8341 2nd ZzZZZzZZzz
# Comment 3: Stop Einstand
# Comment 4: 8331 3rd....
# Comment 5: Sorry kam eben durchs handy nicht durch
# Comment 6: Rest raus zum Einstand
# Comment 7: +30 pk
# 18.0
#
# 2013-08-19T07:15:49+0000
# Dax Short 8384 Stop
# 8394
# Comment 1: 8359 1st
# Comment 2: 8331 2nd
# Comment 3: Stop Einstand
# Comment 4: Rest raus zum in
# Comment 5: + 53
# 39.0
#
# 2013-08-21T10:02:46+0000
# DAX LONG 8280 stop 8268
# Comment 1: Stop auf einstand !
# Comment 2: 8293 1st
# Comment 3: 8296 2nd
# Comment 4: 8300 3rd
# Comment 5: 8310 4th
# Comment 6: rest raus zum einstand !
# Comment 7: + 30 mühsame PK !
# 14.5
#
# 2013-08-21T13:34:27+0000
# DAX SHORT 8290 STOP 8295
# Comment 1: - 5pk
# -5.0
#
# 2013-08-29T08:02:51+0000
# DAX SHORT 8185 STOP 8200
# Comment 1: raus zu 8192 ! händisch !!
# Comment 2: trade ende ! - 7 PK
# Comment 3: reentry
# Comment 4: 8170 1st
# Comment 5: 8160 2nd ! stop einstand
# Comment 6: 8160 auch 3rd
# Comment 7: Rest raus auf in ! + 25 PK !
# 20.0
#
# 2013-09-03T14:20:30+0000
# DAX SHORT 8217 STOP 8233
# Comment 1: 8187 1st & 2nd !!!!!!!
# Comment 2: 8174 3rd !
# Comment 3: stop einstand
# Comment 4: 8157 4th
# Comment 5: 8142 4.5th
# Comment 6: 8107 5th und FLAT !!!!!! 110 PK !!!!!!!!!!!
# 36.5
#
# 2013-09-06T13:37:25+0000
# DAX SHORT 8285 STOP 8297
# Comment 1: 8255 1st & 2nd !!!!!!
# Comment 2: BÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄMMMMM
# Comment 3: STOP AUF EINSTAND !
# Comment 4: 8200 3rd !!!!!
# Comment 5: STOP AUF 8250 nachgezogen
# Comment 6: 8175 4th !
# Comment 7: + 110 PK !!!!!!!!!!!
# Comment 8: rest raus auf 8250 !!!
# Comment 9: Trade Ende ! + 110 PK !!!!!
# 57.5
#
# 2013-09-10T07:17:17+0000
# DAX SHORT 8360 STOP 8370
# Comment 1: -10 pk !
# -10.0
#
# 2013-09-12T11:17:18+0000
# DAX SHORT 8485 STOP 8495
# Comment 1: -10 pk !
# -10.0
#
# 2013-09-12T12:07:55+0000
# DAX SHORT 8511 STOP 8521
# Comment 1: stop einstand !!!
# Comment 2: TVK 8496
# Comment 3: Rest raus zum Einstand
# 7.5
#
# 2013-09-16T13:05:06+0000
# DAX LONG 8615 STOP 8605
# Comment 1: -10 pk ! Trade ende !
# -10.0
#
# 2013-10-02T14:38:10+0000
# DAX LONG 8592 STOP 8580
# Comment 1: stop auf einstand
# Comment 2: 8607 TVK
# Comment 3: 8620 TVK
# Comment 4: 8628 TVK !
# Comment 5: 8635 TVK
# Comment 6: +43 pk bis dato ! rest bleibt drin !
# Comment 7: mini rest raus auf einstand
# 21.5
#
# 2013-10-10T14:05:53+0000
# DAX SHORT 8689 STOP 8696
# Comment 1: 8679 TVK
# Comment 2: STOP AUF EINSTAND
# Comment 3: + 10 PK !
# Comment 4: trade ende
# 5.0
#
# 2013-10-15T07:35:11+0000
# DAX SHORT 8767 STOP 8776
# Comment 1: -9 PK
# -9.0
#
# 2013-10-17T13:40:36+0000
# DAX LONG 8788 STOP 8783
# Comment 1: 8798 tvk
# Comment 2: Stop Einstand
# Comment 3: 8806 tvk
# Comment 4: 8808 fast flat
# Comment 5: 8830 :-). Flat. + 32 Pk.
# Comment 6: +42 pk.
# 14.0
#
# 2013-10-22T08:25:32+0000
# DAX SHORT 8858 STOP 8863
# Comment 1: -5 pk
# -5.0
#
# 2013-10-23T07:29:55+0000
# Dax Long 8911 stop 8901
# Comment 1: -10 Pk.
# -10.0
#
# 2013-10-23T08:09:42+0000
# DAX LONG 8898 STOP 8888
# Comment 1: 8911 TVK
# Comment 2: stop auf 8896
# Comment 3: stop einstand !
# Comment 4: 8918 TVK
# Comment 5: 8928 TVK !
# Comment 6: 8974 TVK
# Comment 7: FLAT zu 9000 ! keine lust mehr und flat vorm weekend immer gut
# Comment 8: +102 PK
# 16.5
