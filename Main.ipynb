# %%
import pandas
import json
f = open('db.txt','r')

data = f.read()
f.close()
messages = json.loads(data)
messages[0]["message"]
# Out:
# [{u'comments': {u'data': [{u'created_time': u'2014-01-22T13:27:20+0000',
#      u'from': {u'id': u'100001920246476', u'name': u'Orkan Kuyas'},
#      u'id': u'688105641234394',
#      u'message': u'27,68 TVK STOP EINSTAND'},
#     {u'created_time': u'2014-01-22T14:09:20+0000',
#      u'from': {u'id': u'100001920246476', u'name': u'Orkan Kuyas'},
#      u'id': u'688119011233057',
#      u'message': u'27,83 TVK'},
#     {u'created_time': u'2014-01-22T15:19:04+0000',
#      u'from': {u'id': u'100001920246476', u'name': u'Orkan Kuyas'},
#      u'id': u'688146477896977',
#      u'message': u'27,95 TVK ! So, hier war das vorherige TOP ca... wirds gebrochen gibts nen squeeze ! Die 28 weiterhin ne Barriere....'},
#     {u'created_time': u'2014-01-22T15:20:12+0000',
#      u'from': {u'id': u'100001920246476', u'name': u'Orkan Kuyas'},
#      u'id': u'688146844563607',
#      u'message': u'dieser Trade ist ein Intraday Trade ! ob ich den halte sage ich noch bescheid !'},
# ...

# %%
# Out:
# u'RWE LONG 27,475 STOP 20 CENT !'
